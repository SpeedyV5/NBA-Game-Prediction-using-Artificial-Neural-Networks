# %%
# Out:
# Kütüphaneler yüklendi!
# Çalışma dizini: c:\Users\user\Desktop\ann odev

# %%
# Out:
# Model metrikleri yüklendi!
#
# Mevcut modeller:
#   - mlp_classifier
#   - mlp_regressor
#   - baseline_gbm
#   - sequence_lstm_classifier
#
# Figürler kaydedilecek: c:\Users\user\Desktop\ann odev\reports\figures

# %%
# Out:
# ...
# CLASSIFICATION METRİKLERİ (Test Set)
# ...
#           Model Split  Accuracy       F1  ROC-AUC  LogLoss    Brier
#  MLP Classifier  Test  0.666545 0.725685 0.710846 0.614343 0.212391
# LSTM Classifier  Test  0.661786 0.720846 0.700758 0.620211 0.215518
#    Baseline GBM  Test  0.668009 0.730300 0.717568 0.609943 0.210620
#
# ...
# REGRESSION METRİKLERİ (Test Set)
# ...
#         Model Split       MAE      RMSE
# MLP Regressor  Test 10.064466 12.913187
#  Baseline GBM  Test 10.036018 12.865979

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1398, in _gcd_import(name, package, level)
#    1397     name = _resolve_name(name, package, level)
# -> 1398 return _find_and_load(name, _gcd_import)
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1370     if module is _NEEDS_LOADING:
# ...
